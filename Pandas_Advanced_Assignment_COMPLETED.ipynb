# %% [markdown]
# <a href="https://colab.research.google.com/github/vermabhineet84-max/AbhineetVerma-UM-Assignments/blob/main/Pandas_Advanced_Assignment_COMPLETED.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
a = pd.Series([100, 200, 300, 400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
print(a[2])
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
print(a.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c', 'a', 'b', 'd']
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
print(a['d'])
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
a = a.sort_index()
print(a)
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
b = pd.Series([800, 450, 100], index=['e', 'f', 'g'])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
a = pd.concat([a, b])

# %%
print(a)
# Out:
# a    200
# b    300
# c    100
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
a = a.sort_values(ascending=False)
print(a.index)
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %%
print(a)
# Out:
# e    800
# f    450
# d    400
# b    300
# a    200
# c    100
# g    100
# dtype: int64

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
df = pd.DataFrame(a, columns=['points'])
print(df)
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200
# c     100
# g     100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
print(df.shape)
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
print(df.index)
print(df.index.equals(a.index))
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')
# True

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
print(df.head())
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200

# %%
print(df.tail())
# Out:
#    points
# d     400
# b     300
# a     200
# c     100
# g     100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df = df.rename(columns={'points': 'points'})
print(df)
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200
# c     100
# g     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
fruits = np.random.choice(['orange', 'mango', 'apple'], size=len(df))

# %%
fruits = pd.Series(fruits)
print(fruits)
# Out:
# 0     mango
# 1     apple
# 2    orange
# 3    orange
# 4    orange
# 5     mango
# 6     mango
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
print(fruits)
# Out:
# e     mango
# f     apple
# d    orange
# b    orange
# a    orange
# c     mango
# g     mango
# dtype: object

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits
print(df.head())
# Out:
#    points  fruits
# e     800   mango
# f     450   apple
# d     400  orange
# b     300  orange
# a     200  orange

# %%
print(df)
# Out:
#    points  fruits
# e     800   mango
# f     450   apple
# d     400  orange
# b     300  orange
# a     200  orange
# c     100   mango
# g     100   mango

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
d1 = pd.DataFrame({'city': ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'], 'Temperature': [15, 22, 20, 26, -2]})

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
print(d1.shape)
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
d2 = pd.DataFrame({'city': ['Bengalaru', 'Coimbatore', 'Srirangam', 'Pondicherry'], 'Temperature': [24, 35, 36, 39]})

# %% [markdown]
# print the shape of this dataframe

# %%
print(d2.shape)
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
d3 = pd.concat([d1, d2], ignore_index=True)
print(d3)
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 5    Bengalaru           24
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
x = d3[d3['Temperature'] <= 20]
print(x)
print(len(x))
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2
# 3

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
print(d3[d3['Temperature'] >= 35])
# Out:
#           city  Temperature
# 6   Coimbatore           35
# 7    Srirangam           36
# 8  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
def is_ut(x):
    return x in ['Chandigarh', 'Pondicherry', 'Delhi']

d3['is_ut'] = d3['city'].apply(is_ut)

# %%
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 5    Bengalaru           24  False
# 6   Coimbatore           35  False
# 7    Srirangam           36  False
# 8  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
def c_to_f(x):
    return x * 9/5 + 32

# %%
print(c_to_f(10))
# Out:
# 50.0

# %%
d3['temp_farenhiet'] = d3['Temperature'].apply(c_to_f)
print(d3)
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15   True            59.0
# 1        Delhi           22   True            71.6
# 2       Kanpur           20  False            68.0
# 3      Chennai           26  False            78.8
# 4       Manali           -2  False            28.4
# 5    Bengalaru           24  False            75.2
# 6   Coimbatore           35  False            95.0
# 7    Srirangam           36  False            96.8
# 8  Pondicherry           39   True           102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
print(d1[d1['city'].apply(is_ut)])
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
print(d1[d1['Temperature'].apply(c_to_f) > 90])
# Out:
# Empty DataFrame
# Columns: [city, Temperature]
# Index: []

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
print(d1.iloc[:3])
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
print(d1.iloc[:, -2:])
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# ## Groupby

# %%
data = {'Team': ['A', 'A', 'B', 'B', 'C', 'C'], 'Product': ['X', 'Y', 'X', 'Y', 'X', 'Y'], 'Sales': [100, 200, 150, 250, 120, 180], 'Profit': [20, 40, 30, 50, 25, 35]}
df2 = pd.DataFrame(data)
print(df2)
# Out:
#   Team Product  Sales  Profit
# 0    A       X    100      20
# 1    A       Y    200      40
# 2    B       X    150      30
# 3    B       Y    250      50
# 4    C       X    120      25
# 5    C       Y    180      35

# %%
print(df2.groupby('Team')['Sales'].sum())
# Out:
# Team
# A    300
# B    400
# C    300
# Name: Sales, dtype: int64

# %%
print(df2.groupby('Team')['Sales'].count())
# Out:
# Team
# A    2
# B    2
# C    2
# Name: Sales, dtype: int64

# %%
print(df2.groupby('Team')['Sales'].agg(['min', 'max']))
# Out:
#       min  max
# Team
# A     100  200
# B     150  250
# C     120  180

# %%
print(df2.groupby(['Team', 'Product'])['Sales'].mean())
# Out:
# Team  Product
# A     X          100.0
#       Y          200.0
# B     X          150.0
#       Y          250.0
# C     X          120.0
#       Y          180.0
# Name: Sales, dtype: float64

# %%
print(df2.groupby(['Team', 'Product'])['Sales'].agg(['min', 'max']))
# Out:
#               min  max
# Team Product
# A    X        100  100
#      Y        200  200
# B    X        150  150
#      Y        250  250
# C    X        120  120
#      Y        180  180
